# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import numpy as np
import pandas as pd

# %%
m = Basemap(projection='merc',llcrnrlat=2,urcrnrlat=38,\
            llcrnrlon=65,urcrnrlon=100,resolution='c')
m.drawcoastlines()
m.drawcountries()
file_path = 'D://Data Sets//Earthquake.csv'
data = pd.read_csv(file_path)
lon=[]
for i in data['longitude']:
    lon.append(i)
lat=[]
for i in data['latitude']:
    lat.append(i)
x,y = m(lon,lat)
sizes= data['mag']
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Indian Subcontinent-Earthquake")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=2,urcrnrlat=38,\
            llcrnrlon=65,urcrnrlon=100,resolution='c')
m.drawcoastlines()
m.drawcountries()
file_path = 'D://Data Sets//final.csv'
data = pd.read_csv(file_path)
lon=[]
for i in data['longitude']:
    lon.append(i)
lat=[]
for i in data['latitude']:
    lat.append(i)
x,y = m(lon,lat)
sizes= data['mag']
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Indian Subcontinent-Final")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=21,urcrnrlat=27,\
            llcrnrlon=88,urcrnrlon=93,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Bangladesh.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']**3
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Bangladesh")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=5,urcrnrlat=25,\
            llcrnrlon=80,urcrnrlon=100,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Bay of Bengal.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']**3
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Bay of Bengal")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=30,urcrnrlat=34,\
            llcrnrlon=75,urcrnrlon=80,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Himachal Pradesh.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']**3
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Himachal Pradesh")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=24,urcrnrlat=37,\
            llcrnrlon=60,urcrnrlon=76,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Pakistan.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']**2
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Pakistan")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=26,urcrnrlat=28,\
            llcrnrlon=88,urcrnrlon=89,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Sikkim.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']**3
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Sikkim")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=29,urcrnrlat=40,\
            llcrnrlon=60,urcrnrlon=75,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Afghanistan.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Afghanistan")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=26,urcrnrlat=30,\
            llcrnrlon=91,urcrnrlon=98,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Arunachal.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']**3
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Arunachal")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=24,urcrnrlat=28,\
            llcrnrlon=89,urcrnrlon=96,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Assam.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']**3
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Assam")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=26,urcrnrlat=29,\
            llcrnrlon=88,urcrnrlon=93,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Bhutan.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']**3
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Bhutan")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=32,urcrnrlat=38,\
            llcrnrlon=72,urcrnrlon=81,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Kashmir.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']**3
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Kashmir")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=26,urcrnrlat=31,\
            llcrnrlon=80,urcrnrlon=89,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Nepal.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']**3
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Nepal")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=-6,urcrnrlat=8,\
            llcrnrlon=90,urcrnrlon=108,resolution='c')
m.drawcoastlines()
m.drawcountries()
m.drawstates()
file_path = 'D://Data Sets//Sumatra.csv'
data = pd.read_csv(file_path)
lat=[]
for i in data['latitude']:
    lat.append(i)
lon=[]
for i in data['longitude']:
    lon.append(i)
x,y = m(lon,lat)
sizes= data['mag']
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.title("Sumatra")
plt.show()

# %%
file_path = 'D://Data Sets//Sumatra.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Sumatra-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Sumatra.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Sumatra-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Nepal.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Nepal-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Nepal.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Nepal-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Afghanistan.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Afghanistan-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Afghanistan.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Afghanistan-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Arunachal.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Arunachal-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Arunachal.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Arunachal-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Bangladesh.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Bangladesh-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Bangladesh.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Bangladesh-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Assam.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Assam-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Assam.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Assam-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Bay of Bengal.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Bay of Bengal-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Bay of Bengal.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Bay of Bengal-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Bhutan.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Bhutan-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Bhutan.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Bhutan-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Himachal Pradesh.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Himachal Pradesh-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Himachal Pradesh.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Himachal Pradesh-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Kashmir.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Kashmir-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Kashmir.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Kashmir-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Pakistan.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Pakistan-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Pakistan.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Pakistan-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Sikkim.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Sikkim-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Sikkim.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Sikkim-mag")
plt.show()

# %%
file_path = 'D://Data Sets//final.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("final-freq")
plt.show()

# %%
file_path = 'D://Data Sets//final.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("final-mag")
plt.show()

# %%
file_path = 'D://Data Sets//Earthquake.csv'
data = pd.read_csv(file_path)
freq=data['mag'].value_counts()
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(freq)
plt.title("Earthquake-freq")
plt.show()

# %%
file_path = 'D://Data Sets//Earthquake.csv'
data = pd.read_csv(file_path)
mag=[]
for i in data['mag']:
    mag.append(i)
fig=plt.figure()
ax=fig.add_axes([.1,.1,1,1])
ax.plot(mag)
plt.title("Earthquake-mag")
plt.show()

# %%
m = Basemap(projection='merc',llcrnrlat=-20,urcrnrlat=40,\
            llcrnrlon=60,urcrnrlon=120,resolution='c')
m.drawcoastlines()
m.drawcountries()
file_path = 'D://Data Sets//Earthquake.csv'
data = pd.read_csv(file_path)
lon=[]
for i in data['longitude']:
    lon.append(i)
lat=[]
for i in data['latitude']:
    lat.append(i)
x,y = m(lon,lat)
sizes= data['mag']**2
m.scatter(x,y,marker='o',c=data['mag'],s=sizes,label=data['mag'])
plt.show()
